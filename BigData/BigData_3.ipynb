# %%
import pandas as pd

# %%
df = pd.read_csv("/content/cleaned_dataset.csv")

# %%
df
# Out:
#                                                    name  \
# 0     OnePlus Nord CE 2 Lite 5G Blue Tide 6GB RAM 12...
# 1     OnePlus Bullets Z2 Bluetooth Wireless in Ear E...
# 2     Samsung Galaxy M33 5G Mystique Green 6GB 128GB...
# 3     OnePlus Nord CE 2 Lite 5G Black Dusk 6GB RAM 1...
# 4     Redmi 10 Power Sporty Orange 8GB RAM 128GB Sto...
# ...                                                 ...
# 4849  Sounce HDMI Cable 4K HighSpeed HDMI Cord 18Gbp...
# 4850  ORICO 25 inch USB C Hard Drive Enclosure USB 3...
# 4851  Aroma NB119 Carter Pro Bluetooth Wireless In E...
# 4852  ASUS MD100 MarshmallowSilent Adj DPI MultiMode...
# 4853  Crysendo Headphone Cushion Pad Compatible with...
#
#                                                   image  \
# 0     https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 1     https://m.media-amazon.com/images/I/51UhwaQXCp...
# 2     https://m.media-amazon.com/images/I/81I3w4J6yj...
# 3     https://m.media-amazon.com/images/I/71V--WZVUI...
# 4     https://m.media-amazon.com/images/I/81OZGH4fZi...
# ...                                                 ...
# 4849  https://m.media-amazon.com/images/I/61KUaE1R97...
# 4850  https://m.media-amazon.com/images/I/61sfwc2UyO...
# 4851  https://m.media-amazon.com/images/I/51qgT9ZuH1...
# 4852  https://m.media-amazon.com/images/I/61hXCL4uC7...
# 4853  https://m.media-amazon.com/images/I/51ODZvKNuS...
#
#                                                    link  no_of_ratings  \
# 0     https://www.amazon.in/OnePlus-Nord-Lite-128GB-...  113956.000000
# 1     https://www.amazon.in/Oneplus-Bluetooth-Wirele...   90304.000000
# 2     https://www.amazon.in/Samsung-Mystique-Storage...   24863.000000
# 3     https://www.amazon.in/OnePlus-Nord-Black-128GB...  113956.000000
# 4     https://www.amazon.in/Redmi-Power-Sporty-Orang...     625.000000
# ...                                                 ...            ...
# 4849  https://www.amazon.in/Sounce-High-Speed-Ethern...      49.000000
# 4850  https://www.amazon.in/ORICO-Enclosure-External...     136.000000
# 4851  https://www.amazon.in/NB119-Carter-Bluetooth-A...      50.000000
# 4852  https://www.amazon.in/ASUS-MD100-Marshmallow-Q...   13268.051261
# 4853  https://www.amazon.in/Crysendo-Headphone-Compa...     231.000000
#
#       discount_price  actual_price  rating  \
# 0            18999.0       19999.0     1.0
# 1             1999.0        2299.0     5.0
# 2            15999.0       24999.0     1.0
# 3            18999.0       19999.0     5.0
# 4            10999.0       18999.0     1.0
# ...              ...           ...     ...
# 4849           149.0         249.0     4.0
# 4850           649.0         850.0     4.0
# 4851           391.0        2299.0     5.0
# 4852          1499.0        2999.0     5.0
# 4853           499.0         849.0     5.0
#
#                                             review_text     brand  \
# 0     Very bad experience with this device xr phone....   OnePlus
# 1     Amazing phone with amazing camera coming from ...   OnePlus
# 2     So I got the device XR just today. The product...   Samsung
# 3     I've been an android user all my life until I ...   OnePlus
# 4     I was delivered a phone that did not work imme...     Redmi
# ...                                                 ...       ...
# 4849                                            Dhamaka    Sounce
# 4850                                            Goodbye     ORICO
# 4851                                            Nothing     Aroma
# 4852                                            Superbb      ASUS
# 4853                                            Nothing  Crysendo
#
#                                     cleaned_review_text sentiment
# 0     bad experience device xr phone back camera fou...  Negative
# 1     amazing phone amazing camera coming device plu...  Positive
# 2     got device xr today product look amazing unfor...  Negative
# 3     ive android user life decided try device xr io...  Positive
# 4     delivered phone work immediately removing box ...  Negative
# ...                                                 ...       ...
# 4849                                            dhamaka  Positive
# 4850                                            goodbye  Positive
# 4851                                            nothing  Positive
# 4852                                            superbb  Positive
# 4853                                            nothing  Positive
#
# [4854 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4854 entries, 0 to 4853
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 4854 non-null   object
#  1   image                4854 non-null   object
#  2   link                 4854 non-null   object
#  3   no_of_ratings        4854 non-null   float64
#  4   discount_price       4854 non-null   float64
#  5   actual_price         4854 non-null   float64
#  6   rating               4854 non-null   float64
#  7   review_text          4854 non-null   object
#  8   brand                4854 non-null   object
#  9   cleaned_review_text  4826 non-null   object
#  10  sentiment            4854 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 417.3+ KB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name                   0
# image                  0
# link                   0
# no_of_ratings          0
# discount_price         0
# actual_price           0
# rating                 0
# review_text            0
# brand                  0
# cleaned_review_text    0
# sentiment              0
# dtype: int64

# %%
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.reset_index(drop=True, inplace=True)

# %%
print(df_cleaned.isnull().sum())
print(f"Rows before: {len(df)}, Rows after: {len(df_cleaned)}")
# Out:
# name                   0
# image                  0
# link                   0
# no_of_ratings          0
# discount_price         0
# actual_price           0
# rating                 0
# review_text            0
# brand                  0
# cleaned_review_text    0
# sentiment              0
# dtype: int64
# Rows before: 4826, Rows after: 4826

# %%
df.columns
# Out:
# Index(['name', 'image', 'link', 'no_of_ratings', 'discount_price',
#        'actual_price', 'rating', 'review_text', 'brand', 'cleaned_review_text',
#        'sentiment'],
#       dtype='object')

# %%
df.groupby('sentiment').count()
# Out:
#            name  image  link  no_of_ratings  discount_price  actual_price  \
# sentiment
# Negative    405    405   405            405             405           405
# Positive   4421   4421  4421           4421            4421          4421
#
#            rating  review_text  brand  cleaned_review_text
# sentiment
# Negative      405          405    405                  405
# Positive     4421         4421   4421                 4421

# %%
sentiment_counts = df['sentiment'].value_counts()
print(sentiment_counts)
# Out:
# sentiment
# Positive    4421
# Negative     405
# Name: count, dtype: int64

# %%
count = (df['rating'] > 3).sum()
print(f"{count} products have rating more than 3")
# Out:
# 4421 products have rating more than 3
